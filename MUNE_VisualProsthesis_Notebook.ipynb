# %% [markdown]
# <a href="https://colab.research.google.com/github/juanjogomez/MUNE_NeuroProsthetics/blob/main/MUNE_VisualProsthesis_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎥 **Visual Prosthesis Simulation Notebook**
#
# ## Simulating Phosphene-Based Vision in Visual Prostheses
#
# This notebook guides you step by step to understand and replicate the experience of a visual prosthesis using phosphene dots. It enables users to simulate how different neuroprosthetic devices process visual input and translate it into artificial sight.
#
# ### 🔬 Master in Neurotechnology - Universidad Politécnica de Madrid
# #### 🏥 Neuroprosthetics Course
# #### 📅 March 2025

# %% [markdown]
# # Step 1: Setup (Run Once)
# Run the next 3 code cells to install packages, import libraries, and create folders.

# %%
# !pip -q install opencv-python imageio scikit-image ipywidgets

# %%
import os
import shutil
import datetime
import cv2
import imageio
import numpy as np
import ipywidgets as widgets
from skimage.transform import resize
from IPython.display import display, Video

try:
    from google.colab import files
    IS_COLAB = True
except ImportError:
    files = None
    IS_COLAB = False

root_dir = "/content" if IS_COLAB else os.getcwd()
base_dir = os.path.join(root_dir, "MUNE_NeuroProsthetics_PhosphenesSimulator", datetime.datetime.now().strftime("%Y%m%d_%H%M%S"))
input_dir = os.path.join(base_dir, "input")
output_dir = os.path.join(base_dir, "output")

os.makedirs(input_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)
print(f"Working directory: {base_dir}")
# Out:
# Working directory: /home/juanjo/MUNE_NeuroProsthetics/MUNE_NeuroProsthetics_PhosphenesSimulator/20260412_195951

# %% [markdown]
# # Step 2: Choose Prosthesis and Parameters
# Pick a preset and adjust sliders if needed.

# %%
prosthesis_presets = {
    "Argus II": {"num_phosphenes": 300, "visual_field": 25, "noise_level": 0.20},
    "Dobelle Eye": {"num_phosphenes": 220, "visual_field": 35, "noise_level": 0.25},
}

prosthesis_selector = widgets.Dropdown(
    options=list(prosthesis_presets.keys()),
    value="Argus II",
    description="Preset:",
    layout=widgets.Layout(width="350px")
)

def add_prosthesis_preset(name, num_phosphenes, visual_field, noise_level):
    prosthesis_presets[name] = {
        "num_phosphenes": int(num_phosphenes),
        "visual_field": int(visual_field),
        "noise_level": float(noise_level),
    }
    prosthesis_selector.options = list(prosthesis_presets.keys())

# %%
def update_parameters(change=None):
    selected_preset = prosthesis_presets[prosthesis_selector.value]
    num_phosphenes.value = selected_preset["num_phosphenes"]
    visual_field.value = selected_preset["visual_field"]
    noise_level.value = selected_preset["noise_level"]

num_phosphenes = widgets.IntSlider(min=50, max=5000, step=50, value=300, description="Phosphenes")
visual_field = widgets.IntSlider(min=10, max=100, step=5, value=25, description="Field (deg)")
noise_level = widgets.FloatSlider(min=0, max=1, step=0.05, value=0.20, description="Noise")
edge_detection = widgets.Checkbox(value=False, description="Edge detection")
circular_mask_option = widgets.Checkbox(value=True, description="Circular mask")

prosthesis_selector.observe(update_parameters, names="value")
update_parameters()

def create_phosphene_grid(h, w, num_phosphenes=500, dot_radius=3):
    mask = np.zeros((h, w), dtype=np.uint8)
    grid_spacing = max(1, int(np.sqrt((h * w) / max(1, num_phosphenes))))

    for y in range(0, h, grid_spacing):
        for x in range(0, w, grid_spacing):
            jitter_x = np.random.randint(-max(1, grid_spacing // 4), max(2, grid_spacing // 4 + 1))
            jitter_y = np.random.randint(-max(1, grid_spacing // 4), max(2, grid_spacing // 4 + 1))
            x_pos = np.clip(x + jitter_x, 0, w - 1)
            y_pos = np.clip(y + jitter_y, 0, h - 1)
            cv2.circle(mask, (x_pos, y_pos), radius=dot_radius, color=255, thickness=-1)

    return mask > 0

def create_circular_mask(h, w, center=None, radius=None):
    if center is None:
        center = (int(w / 2), int(h / 2))
    if radius is None:
        radius = min(center[0], center[1], w - center[0], h - center[1])

    y, x = np.ogrid[:h, :w]
    dist_from_center = np.sqrt((x - center[0]) ** 2 + (y - center[1]) ** 2)
    return dist_from_center <= radius

def phosphene_simulation(frame, num_phosphenes, noise_level, visual_field, edge_detection, circular_mask):
    h, w, _ = frame.shape
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    if edge_detection:
        gray_frame = cv2.Canny(gray_frame, 50, 150)

    phosphene_mask = create_phosphene_grid(h, w, num_phosphenes=num_phosphenes)
    flicker_effect = np.random.uniform(0.7, 1.2, size=(h, w))
    phosphene_image = np.zeros_like(gray_frame, dtype=np.uint8)
    phosphene_vals = gray_frame[phosphene_mask] * flicker_effect[phosphene_mask]
    phosphene_image[phosphene_mask] = np.clip(phosphene_vals, 0, 255).astype(np.uint8)

    if noise_level > 0:
        sigma = 255 * noise_level * 0.20
        noise = np.random.normal(0, sigma, phosphene_image.shape)
        phosphene_image = np.clip(phosphene_image.astype(np.float32) + noise, 0, 255).astype(np.uint8)

    if circular_mask:
        radius = int((visual_field / 180) * (min(h, w) / 2))
        mask = create_circular_mask(h, w, radius=max(1, radius))
        final_image = np.zeros_like(phosphene_image)
        final_image[mask] = phosphene_image[mask]
    else:
        final_image = phosphene_image

    return cv2.cvtColor(final_image, cv2.COLOR_GRAY2BGR)

def process_video(video_path, output_path, num_phosphenes, noise_level, visual_field, edge_detection, circular_mask):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError(f"Could not open input video: {video_path}")

    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    fps = cap.get(cv2.CAP_PROP_FPS)
    fps = int(fps) if fps and fps > 0 else 20
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        processed_frame = phosphene_simulation(
            frame, num_phosphenes, noise_level, visual_field, edge_detection, circular_mask
        )
        out.write(processed_frame)

    cap.release()
    out.release()

# %% [markdown]
# # Step 3 (Optional): Add a New Prosthesis in One Line
# Format: Name,Phosphenes,VisualField,Noise
# Example: MyDevice,420,30,0.25

# %%
quick_preset = widgets.Text(
    value="MyDevice,420,30,0.25",
    description="New preset:",
    layout=widgets.Layout(width="500px"),
)
add_button = widgets.Button(description="Add Preset")
add_status = widgets.Output()

def on_add_preset(_):
    with add_status:
        add_status.clear_output()
        try:
            name, n, vf, nz = [x.strip() for x in quick_preset.value.split(",")]
            add_prosthesis_preset(name, int(n), int(vf), float(nz))
            prosthesis_selector.value = name
            print(f"Added: {name}")
        except Exception:
            print("Use format: Name,Phosphenes,VisualField,Noise")

add_button.on_click(on_add_preset)
display(quick_preset, add_button, add_status)
# Out:
# Text(value='MyDevice,420,30,0.25', description='New preset:', layout=Layout(width='500px'))
# Button(description='Add Preset', style=ButtonStyle())
# Output()

# %% [markdown]
# # Step 4: Load MP4 and Generate Output
# Colab: upload from browser.
# Ubuntu/Jupyter: paste local file path when prompted, then click Generate.

# %%
last_output_path = None

def generate_phosphenes(_):
    global last_output_path

    if "input_video_path" not in globals() or not os.path.exists(input_video_path):
        print("Please upload/select an MP4 file first (Step 4).")
        return

    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    prosthesis_name = prosthesis_selector.value.replace(" ", "_")
    output_filename = f"{prosthesis_name}_phosphene_output_{timestamp}.mp4"
    output_path = os.path.join(output_dir, output_filename)

    process_video(
        input_video_path,
        output_path,
        num_phosphenes.value,
        noise_level.value,
        visual_field.value,
        edge_detection.value,
        circular_mask_option.value,
    )

    last_output_path = output_path
    print(f"Processed video saved at: {output_path}")
    display(Video(output_path, embed=True, html_attributes="controls"))

def download_last_output(_):
    if not (last_output_path and os.path.exists(last_output_path)):
        print("Generate a video first.")
        return

    if IS_COLAB:
        files.download(last_output_path)
    else:
        print(f"Output saved at: {last_output_path}")

# %%
if IS_COLAB:
    uploaded = files.upload()
    video_filename = next(iter(uploaded.keys()))
    if not video_filename.lower().endswith(".mp4"):
        raise ValueError("Please upload an .mp4 file.")
    input_video_path = os.path.join(input_dir, video_filename)
    os.rename(video_filename, input_video_path)
else:
    local_video_path = input("Enter full path to a local .mp4 file: ").strip()
    if not local_video_path.lower().endswith(".mp4"):
        raise ValueError("Please provide an .mp4 file.")
    if not os.path.exists(local_video_path):
        raise FileNotFoundError(f"File not found: {local_video_path}")

    src_path = os.path.abspath(local_video_path)
    dst_path = os.path.abspath(os.path.join(input_dir, os.path.basename(local_video_path)))

    # If the file is already inside input_dir, avoid copying over itself.
    if src_path == dst_path:
        input_video_path = src_path
    else:
        shutil.copy2(src_path, dst_path)
        input_video_path = dst_path

print(f"Input video ready: {input_video_path}")
# Out:
# Input video ready: /home/juanjo/MUNE_NeuroProsthetics/MUNE_NeuroProsthetics_PhosphenesSimulator/20260412_195951/input/video_people_walking.mp4

# %%
generate_button = widgets.Button(description="Generate Phosphene Video", button_style="success")
download_button = widgets.Button(description="Download Last Output")

generate_button.on_click(generate_phosphenes)
download_button.on_click(download_last_output)

display(
    prosthesis_selector,
    num_phosphenes,
    visual_field,
    noise_level,
    edge_detection,
    circular_mask_option,
    generate_button,
    download_button,
)
# Out:
# Dropdown(description='Preset:', index=3, layout=Layout(width='350px'), options=('Argus II', 'Dobelle Eye', 'Or…
# IntSlider(value=400, description='Phosphenes', max=5000, min=50, step=50)
# IntSlider(value=30, description='Field (deg)', min=10, step=5)
# FloatSlider(value=0.25, description='Noise', max=1.0, step=0.05)
# Checkbox(value=False, description='Edge detection')
# Checkbox(value=False, description='Circular mask')
# Button(button_style='success', description='Generate Phosphene Video', style=ButtonStyle())
# Button(description='Download Last Output', style=ButtonStyle())

# %%
if last_output_path and os.path.exists(last_output_path):
    print(f"Last output: {last_output_path}")
    display(Video(last_output_path, embed=True, html_attributes="controls"))
else:
    print("No generated output yet.")
# Out:
# Last output: /home/juanjo/MUNE_NeuroProsthetics/MUNE_NeuroProsthetics_PhosphenesSimulator/20260412_195951/output/Orion_(Cortical)_phosphene_output_20260412_200733.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# # Optional: Cleanup

# %%
import shutil

def cleanup_folders(_):
    remove_all = remove_folders_checkbox.value
    shutil.rmtree(input_dir, ignore_errors=True)
    shutil.rmtree(output_dir, ignore_errors=True)

    if remove_all:
        shutil.rmtree(base_dir, ignore_errors=True)
        print("All files and folders removed.")
    else:
        os.makedirs(input_dir, exist_ok=True)
        os.makedirs(output_dir, exist_ok=True)
        print("Input/output files removed. Folders kept.")

remove_folders_checkbox = widgets.Checkbox(value=False, description="Remove base folder too")
cleanup_button = widgets.Button(description="Clean Up")
cleanup_button.on_click(cleanup_folders)
display(remove_folders_checkbox, cleanup_button)
# Out:
# Checkbox(value=False, description='Remove All Folders')
# Button(description='Clean Up Files', style=ButtonStyle())
# All files and folders have been deleted.
